# %% [markdown]
# <a href="https://colab.research.google.com/github/ttvhh/CS114.K21/blob/master/Car_License_Plate_Recognition_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Automatic License Plate Recognition**

# %% [markdown]
# ## **Phần I: Mô tả đồ án**
#
# *
# *   List item

# %% [markdown]
# ## **Phần II: Các bước thực hiện đồ án**
#
# *   Bước 1: Chuẩn bị dữ liệu là các chữ số nhằm mục đích train cho model có thể nhận diện được các ký tự. Sau đó lưu ra file riêng.
#
# *   Bước 2: Train model với dữ liệu đã có.
#
# *   Bước 3: Đưa một file ảnh, trong đó là ảnh toàn cảnh của chiếc xe hoặc có thể là một phần chiếc xe (có bao gồm biển số xe cần nhận diện).
#
# *   Bước 4: Để có thể tách biển số ra khỏi ảnh và thực hiện skew ảnh.
#
# *   Bước 5: Thực hiện grayscale sau đó threshold để có thể phân tách trắng đen và đồng thời khử nhiễu càng nhiều càng tốt.
#
# *   Bước 6: Tìm các contour trong ảnh sau khi đã được grayscale và threshold. Giữ các contour có khả năng cao là chữ số.
#
# *   Bước 7: Nhận diện các contour được giữ lại bằng model đã qua quá trình training ở bước 2.
#
# *   Bước 8: In ra các số liệu cần thiết và kết quả biển số nhận diện được ra màn hình.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/ttvhh/CS114.K21

# %% [markdown]
# Giải nén dataset

# %%
# !unrar x "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data.rar" "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/"
#!unzip "/content/drive/My Drive/desktop1.zip" -d "/content/drive/My Drive/"

# %% [markdown]
# Cài đặt các thư viện cần thiết từ file ```setup.txt```

# %%
# !pip install -r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt

# %% [markdown]
# ## **Phần III: Hiện thực đồ án**

# %% [markdown]
# ### **1. Chuẩn bị dữ liệu**

# %% [markdown]
# #### 1.1. Cài đặt thư viện
#
# Trước hết ta cần cài đặt một số thư viện cần thiết phục vụ cho đồ án:
#
# *   cv2 (openCV)
# *   os
# *   numpy
# *   glob

# %%
import cv2
import os
import numpy as np
import glob

# %% [markdown]
# #### 1.2. Lấy dữ liệu các ký tự

# %% [markdown]
# Từ đường dẫn github, ta lấy về bộ dataset

# %%
digit_w = 30
digit_h = 60

write_path="/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data"

def get_digit_data(path):#:, digit_list, label_list):

    digit_list = []
    label_list = []

    # Dữ liệu từ 0 đến 9
    for number in range(10):
        i=0
        for img_org_path in glob.iglob(path + str(number) + '/*.jpg'):
            print(img_org_path)
            img = cv2.imread(img_org_path, 0)
            img = np.array(img)
            img = img.reshape(-1, digit_h * digit_w)

            print(img.shape)

            digit_list.append(img)
            label_list.append([int(number)])

    # Dữ liệu từ A đến Z
    for number in range(65, 91):
        #number = chr(number)
        print(number)
        i=0
        for img_org_path in glob.iglob(path + str(number) + '/*.jpg'):
            print(img_org_path)
            img = cv2.imread(img_org_path, 0)
            img = np.array(img)
            img = img.reshape(-1, digit_h * digit_w)

            print(img.shape)

            digit_list.append(img)
            label_list.append([int(number)])

    return  digit_list, label_list

# %% [markdown]
# #### 1.3. Train SVM model

# %%
#lấy dữ liệu
digit_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/"
digit_list, label_list = get_digit_data(digit_path)

digit_list = np.array(digit_list, dtype=np.float32)
digit_list = digit_list.reshape(-1, digit_h * digit_w)

label_list = np.array(label_list)
label_list = label_list.reshape(-1, 1)

# Tạo model rỗng
svm_model = cv2.ml.SVM_create()

# Cấu hình công thức liên quan
svm_model.setType(cv2.ml.SVM_C_SVC)

# Khởi tạo với 1 trong nhiều kernels đã được địng nghĩa từ trước
# Ở đây chọn kernel INTER - Histogram Intersection Kernel:
svm_model.setKernel(cv2.ml.SVM_INTER)

svm_model.setTermCriteria((cv2.TERM_CRITERIA_MAX_ITER, 100, 1e-6))

# Train model 
svm_model.train(digit_list, cv2.ml.ROW_SAMPLE, label_list)

# Lưu dữ liệu phục vụ cho các công đoạn sau
svm_model.save("svm.xml")
# Out:
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46513_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/9221.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46631_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46610_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47015_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46304_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46937_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46378_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46848_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46574_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46314_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46817_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46697_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46454_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46946_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46587_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/2575.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46549_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46888_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46813_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46905_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46373_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46906_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46410_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/1163.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46514_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46355_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46369_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46468_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46512_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46565_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46762_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46513_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46713_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46697_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46594_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46883_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46926_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47003_9.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46918_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46538_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46368_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46326_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46367_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46921_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46685_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46681_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46608_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47008_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46553_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46410_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46817_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/7075.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46793_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46505_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47004_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46551_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46527_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46325_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46914_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46639_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46396_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46331_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46702_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46519_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46514_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46457_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46685_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46513_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46567_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46540_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46464_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46321_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46410_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46468_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46556_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44680_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46507_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46514_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46329_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46392_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46651_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46567_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46425_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46707_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46368_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46518_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44688_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46512_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46392_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46436_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46524_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46376_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/6498.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46713_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46457_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/1817.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46707_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46601_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46321_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46548_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46540_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44688_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/6490.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46584_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46524_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46651_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46713_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46434_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46608_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46502_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/759.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46839_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46513_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46518_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/27.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/51797_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46639_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46588_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48404_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48500_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46563_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46505_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46550_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47292_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46423_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46514_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46311_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46548_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46359_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1995_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1881_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46878_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46403_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46440_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1995_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48936_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/194918_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49249_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46310_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46373_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/44682_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46538_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46359_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/51396_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2018.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46434_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49146_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47047_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/192901_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46608_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47954_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48166_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46440_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49191_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49001_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48454_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46570_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46464_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46567_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46328_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46310_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46691_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48803_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46542_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46397_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48446_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46527_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48337_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2045_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46710_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2052_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46311_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47060_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/50798_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/1371.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47959_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/191694_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47959_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/21041.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47703_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46388_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46524_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/3778.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46811_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48179_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48019_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/1463.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47082_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/50221_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/9223.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48822_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46367_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46356_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46310_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46305_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46311_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46325_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/44688_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46310_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46359_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3925_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46570_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3987_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48959_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46354_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46538_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46423_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3925_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48239_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46572_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46310_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46374_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46628_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46368_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48959_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46431_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46531_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46588_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/195079_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/7518.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/47174_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46587_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46305_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46366_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46551_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46397_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/6753.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46519_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46348_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46325_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46378_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46392_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46542_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46392_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46628_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/47549_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46457_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46329_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3962_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46425_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46588_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46367_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46403_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46587_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46304_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46434_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46311_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46519_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/53510_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46320_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/49041_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46359_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46505_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46373_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46329_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46328_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/8697.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46527_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46610_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46572_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/1672.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46392_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2558.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46314_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46396_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46563_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46348_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44680_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46591_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46464_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44680_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46427_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46321_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46518_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46314_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46304_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46507_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46326_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46325_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46359_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46463_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46584_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46505_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46553_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46651_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46601_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46328_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46685_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46331_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/6783.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46427_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46354_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46366_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46355_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46514_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46376_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46542_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46366_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/4640.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46463_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46621_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46527_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46705_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46608_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/9404.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44682_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46464_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46457_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44688_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46702_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/49172_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/49099_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48118_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48304_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48140_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48996_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46531_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46463_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46304_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46549_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46513_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46549_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48905_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48118_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48341_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46545_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48910_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/3603.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46304_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46427_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46530_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47015_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46443_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/8593.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47043_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/7869.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46697_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/44680_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46702_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47015_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46553_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47108_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47187_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47067_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47082_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46685_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47038_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46308_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46524_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47038_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47122_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46437_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47045_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46321_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/2647.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46847_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46567_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47205_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47022_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46308_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46629_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47061_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47262_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46781_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46882_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46464_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46519_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46930_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47042_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46601_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52221_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52227_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/194961_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52189_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52531_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52530_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52635_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52278_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46584_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/2318.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52201_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/48341_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52272_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52504_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52100_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/9.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52515_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52496_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52157_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52167_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/2858.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52089_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/48341_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52185_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52091_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52278_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46709_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52297_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46964_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52264_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52566_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52636_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52530_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46843_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52139_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52239_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52562_5.jpg
# (1, 1800)
# 65
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0.jpg
# (1, 1800)
# 66
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46880_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/44682_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46685_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47338_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48203_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48340_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46507_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48183_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46553_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48434_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46930_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47443_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48476_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47694_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47263_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48146_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47165_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47880_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47657_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47781_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47611_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48361_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47595_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46898_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48381_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46948_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47536_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46457_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46356_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46712_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47631_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47556_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46551_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47819_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46359_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47526_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47519_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47820_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46376_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46348_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46321_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47365_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48316_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46567_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46942_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47267_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47262_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46329_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48004_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47132_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46331_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47047_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48412_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47764_1.jpg
# (1, 1800)
# 67
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46514_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46607_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46815_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46601_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48069_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46710_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48111_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47292_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46818_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46693_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46665_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48046_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47012_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46328_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47006_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46540_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46513_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46714_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47053_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47947_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47203_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47023_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/44688_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47074_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/44680_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46621_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47015_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47555_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47341_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46807_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46707_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48192_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47416_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47390_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47060_1.jpg
# (1, 1800)
# 68
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/47311_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/48068_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/51841_7.jpg
# (1, 1800)
# ...
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52259_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52594_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/51370_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/49162_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/51826_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/50178_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/48015_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/48990_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/192933_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/47389_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/46610_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/194745_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52198_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/49091_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/53098_1.jpg
# (1, 1800)
# 81
# 82
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/53768_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52760_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50335_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51906_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/49493_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48138_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/53478_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/192936_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48121_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/47818_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52636_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48729_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50081_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/193028_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51741_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51487_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/49483_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48888_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/46681_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50221_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51600_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50105_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51212_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52569_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/194511_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51549_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50344_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48097_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/47251_2.jpg
# (1, 1800)
# 83
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/47768_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/47591_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/192770_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/53581_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/52151_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/49638_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48591_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/193213_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/194945_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/52406_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/194582_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48187_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48537_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/192320_1.jpg
# (1, 1800)
# 84
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46320_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46631_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46556_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/48463_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46373_1.jpg
# (1, 1800)
# 85
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/52750_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194986_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/48613_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193917_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/53472_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47905_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193216_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46922_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/192265_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46937_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/48449_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/50957_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194198_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193651_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193208_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46935_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/52226_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/49563_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/195194_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/49572_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47004_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51098_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/191922_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46397_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/192944_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51870_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51996_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193119_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194219_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/53277_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47642_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194001_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46403_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51932_1.jpg
# (1, 1800)
# 86
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46305_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/192252_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46355_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191610_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46964_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/47413_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/47018_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/193231_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191582_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191929_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191745_1.jpg
# (1, 1800)
# 87
# 88
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47170_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47588_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192238_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46375_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191899_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/48853_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46955_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191793_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46888_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191819_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46954_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191854_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47188_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46367_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192361_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47117_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191600_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46691_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192383_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191567_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191759_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47370_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46311_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47891_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192195_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47206_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47596_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192052_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191751_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46907_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46779_1.jpg
# (1, 1800)
# 89
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193054_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193504_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/47471_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/194806_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/49308_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/52500_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/194966_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/53642_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/46959_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/49253_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193050_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/46841_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193572_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/50271_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/50930_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/192102_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/48548_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/51807_0.jpg
# (1, 1800)
# 90
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3558_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47560_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/193092_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46822_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46550_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3758_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/52374_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48063_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47220_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47866_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3762_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/192204_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/50728_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48336_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/51946_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46454_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46705_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/49113_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46903_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3469_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/49559_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48165_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47949_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46463_3.jpg
# (1, 1800)

# %% [markdown]
# ### **2. Xử lý biển số**
#
# Truóc khi bắt đầu, ta cần áp dụng một số kỹ thuật xử lý để giảm nhiễu (noise) và làm nổi bật các đặc trưng chính (key features) của các ký tự cần nhận dạng.
#
# *   Load ảnh
# *   Tách biển số bằng WPOD
# *   Grayscale, threshold và khử nhiễu
# *   Tìm contour
#
# Quá trình này sẽ hiện thực một số kĩ thuật sau:
# 1. 255-scale Conversion
# 2. Grayscale Conversion
# 3. Blurring
# 4. Threshold Binary, Imvetered

# %% [markdown]
# #### 2.1. Tách biển số
#
# Sử dụng WPOD để thực hiện công việc tách biển số ra từ tấm hình đầu vào

# %% [markdown]
# ##### 2.1.1. Cài đặt thư viện

# %%
# pylint: disable=invalid-name, redefined-outer-name, missing-docstring, non-parent-init-called, trailing-whitespace, line-too-long
from os.path import splitext
import cv2
import numpy as np
from keras.models import model_from_json

# %% [markdown]
# ##### 2.1.2. Load model
#
# Model này đã được xây dựng sẵn.

# %%
def load_model(path):
    path = splitext(path)[0]
    with open('%s.json' % path, 'r') as json_file:
        model_json = json_file.read()
    model = model_from_json(model_json, custom_objects={})
    model.load_weights('%s.h5' % path)
    return model

# %% [markdown]
# #### 2.2. Cấu hình thông số

# %% [markdown]
# ##### 2.2.1. Cài đặt thư viện

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Đường dẫn ảnh
img_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/test/test.jpg"

# Load pre-trained license plate detecting model (WPOD-net)
wpod_net_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/wpod-net_update1.json"
wpod_net = load_model(wpod_net_path)

# Đọc file ảnh đầu vào
Ivehicle = cv2.imread(img_path)

# Khởi tạo kích thước lớn nhất và nhỏ nhất của 1 chiều ảnh
Dmax = 608
Dmin = 288

# Lấy tỷ lệ giữa W và H của ảnh và tìm ra chiều nhỏ nhất
ratio = float(max(Ivehicle.shape[:2])) / min(Ivehicle.shape[:2])
side = int(ratio * Dmin)
bound_dim = min(side, Dmax)

_ , LpImg, lp_type = detect_lp(wpod_net, im2single(Ivehicle), bound_dim, lp_threshold=0.5)
# Out:
# Loading model successfully...
# (24, 32, 8)
# [<__main__.DLabel object at 0x7f98c542e5f8>]
# [<__main__.DLabel object at 0x7f98c542e160>]

# %% [markdown]
# ##### 2.2.1. Cấu hình tham số cho model SVM

# %%
# Cấu hình tham số cho OCR model (SVM)

# Kích thước kí tự
digit_w = 30 # Width
digit_h = 60 # Height

# Load model
model_svm = cv2.ml.SVM_load('/content/CS114.K21/Automatic_License_Plate_Detection_SVM/svm.xml')

# %% [markdown]
# ##### 2.2.2. Hàm loại bỏ các ký tự không liên quan
#
# Ở bước này, ta cần phải kiểm tra xem trên biển số có thể tồn tại những ký tự không hợp lý hay không.
#
# Do đó, nguyên lý cơ bản là ta cần phải tạo hàm ```fine_tune``` để kiểm tra các ký tự hợp lệ (được gán trong biến ```char_list``` ở bên dưới rồi gán sang một string khác, còn các ký tự không hợp lệ đã tự động được loại bỏ.

# %%
# Định nghĩa các ký tự có mặt trên biển số
char_list =  '0123456789ABCDEFGHKLMNPRSTUVXYZ'

# Hàm fine_tune dùng để loại bỏ các ký tự không liên quan
def fine_tune(lp):
    newString = ""
    for i in range(len(lp)):
        if lp[i] in char_list:
            newString += lp[i]
    return newString

# %% [markdown]
# #### 2.3. Chuyển đổi ảnh số

# %%
# Chuyển đổi ảnh biển số
# Scale, tính toán các giá trị tuyệt đối và sau đó chuyển đổi kết quả sang dạng 8-bit
LpImg[0] = cv2.convertScaleAbs(LpImg[0], alpha=(255.0))

roi = LpImg[0]

# %% [markdown]
# #### 2.4. Chuyển đổi Grayscale
#
# Trong xử lý ảnh, việc chuyển đổi ảnh màu sang ảnh xám là công việc vô cùng phổ biến. Ảnh màu thực chất là tập hợp của nhiều ma trận có cùng kích thước.
#
# Công việc xử lý thông tin trên ảnh sẽ trở nên dễ dàng hơn nếu ta chỉ cần xử lý dữ liệu trên một ma trận số thay vì nhiều ma trận số.
#
# Do đó, việc biến đổi ảnh màu về ảnh số (Grayscale Conversion) chính là biến đổi thông tin ảnh về một ma trận số hai chiều duy nhất
#
# Hiện thực: sử dụng câu lệnh
# > ``` cvtColor(source, dest, mode) ```
#
# *   ```source``` : ảnh màu gốc
# *   ```dest``` : ảnh xám đã chuyển đổi
# *   ```mode``` : độ chuyển đổi màu
# *   Ở đây, ta dùng chế độ ```CV_BGR2GRAY``` để chuyển từ ảnh mày từ format RGB (Red - Green - Blue) sang ảnh xám (Gray)

# %%
# Áp dụng kỹ thuật Grayscale Conversion để chuyển đổi ảnh biển số về ảnh xám
gray = cv2.cvtColor( LpImg[0], cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #### 2.5. Chuyển đổi Threshold Binary, Inverted
#
# Ảnh đen trắng thường được ứng dụng trong bài toán phân vùng ảnh (Image Segmentation).
#
# Ảnh đen trắng chỉ có hai màu là màu đen với giá trị là ```0``` và màu trắng với giá trị là ```255```.
#
# Do đó ta phải tìm cách biến đổi ảnh xám đã được chuyển đổi ở bước trên (hay là một ma trận 2 chiều với mỗi ô (pixel) có giá trị trong khoảng ```0-255``` thành một ma trận 2 chiều với mỗi ô có giá trị bây giờ chỉ là ```0``` hoặc ```255```.
#
# Vì vậy, ở bước này, ta cần đưa ra một ngưỡng (threshold) nhằm mục đích xác định trên ảnh đâu là điểm ảnh màu đen và đâu là điểm ảnh màu trắng
#
# Ở đây ta dùng kỹ thuật ***Threshold Binary, Inverted***:
#
# >pixel(x,y) = 0 nếu gray(x,y) > threshold
#
# >pixel(x,y) = 255 nếu gray(x,y) <= threshold
#
# Hiện thực:
#
# > ```threshold(src, dst, thres, max_val, type)```
#
# *   ```src```: ảnh xám gốc
# *   ```dst```: ảnh đen trắng đã thay đổi
# *   ```thres```: ngưỡng
# *   ```max_val```: ngưỡng trắng
# *   ```type```: loại biến đổi. Ở đây ```type = 1```, tức biến đổi đen trắng ngược với định nghĩa ở trên

# %%
# Áp dụng Threshold Binary, Inverted để phân tách số và nền
binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)[1]

plt.imshow(binary)

# %% [markdown]
# #### 2.6. Tìm và sắp xếp các contours
#
# Sử dụng hàm ```findContours``` của OpenCV để xác định những tọa độ điểm của các ký tự. Hàm này được xây dựng dựa trên lý thuyết đơn giản: contour là tập các điểm liên tục tạo thành đường cong (curve) - boundary mà có đặc điểm chung là các điểm có cùng/gần xấp xỉ một giá trị màu sắc, hoặc cùng mật độ (intensity).
#
# > ```findContours(bin_img, type, method)```
#
# *   ```bin_img```: ảnh nhị phân gốc
# *   ```type```: dạng contour. Ở bài này dùng ```RETR_LIST```
# *   ```method```: phương thức. Ở bài này dùng ```CHAIN_APPROX_SIMPLE```

# %%
# Segment kí tự
kernel3 = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
thre_mor = cv2.morphologyEx(binary, cv2.MORPH_DILATE, kernel3)
cont, _  = cv2.findContours(thre_mor, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# Ở đây ta tạo một hàm ```sort_contours``` duyệt hết các contour tìm được từ trái sang phải. Điều này quan trọng vì ta không chỉ muốn nhận dạng ký tự mà còn mong muốn sắp xếp chúng theo đúng trật tự.

# %%
# Hàm sắp xếp các contour từ trái sang phải theo đúng trật tự
def sort_contours(cnts):

    reverse = False
    i = 0
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes), key=lambda b: b[1][i], reverse=reverse))
    return cnts

# %% [markdown]
# Bởi vì ta biết rằng height của ký tự có giá trị lớn hơn width nên ta có thể lọc những contours không liên quan bằng cách chỉ chọn những contours có tỉ lệ height/width nằm trong khoảng ```1-3.5```
#
#
# Hơn nữa, ta cũng biết rằng mỗi ký tự trong biển số có height lớn hơn 1 nửa chiều cao thật của biển số, vì vậy ta có thể chọn thêm các contour có giá trị height từ 60% giá trị height của biển số.
#
# Sau khi xử lý các contours ở trên, trích xuất các giá trị cần thiết và đưa vào model SVM đã thực hiện công hiện predict đó là chữ số nào.
#
# Cuối cùng chính là ghép cả chuỗi số lại rồi hiển thị ra màn hình giá trị của biển số.

# %%
# Khởi tạo chuỗi rỗng để lưu trữ thông tin biển số
plate_info = ""

for c in sort_contours(cont):
    (x, y, w, h) = cv2.boundingRect(c)

    # Tỉ lệ h/w dùng để lọc những ký tự không liên quan
    ratio = h/w

      # Chọn các contour thỏa mãn yêu cầu tỉ lệ h/w phải nằm trong 
      # khoảng từ 1.5 đến 3.5
      if 1.5 <= ratio <= 3.5: 

        # Áp dụng kết quả sau khi áp dụng kĩ thuật ROI 
        # để chọn các contour có chiều cao từ 60% chiều cao biển số
        if h/roi.shape[0]>=0.6:

            # Vẽ khung chữ nhật quanh chữ số
            cv2.rectangle(roi, (x, y), (x + w, y + h), (0, 255, 0), 2)

            # Tách số và resize
            curr_num = thre_mor[y:y+h,x:x+w]
            curr_num = cv2.resize(curr_num, dsize=(digit_w, digit_h))
                
            # Áp dụng ROI - Region of Interest
            _, curr_num = cv2.threshold(curr_num, 30, 255, cv2.THRESH_BINARY)
            curr_num = np.array(curr_num,dtype=np.float32)
            curr_num = curr_num.reshape(-1, digit_w * digit_h)

            # Load vào model SVM
            result = model_svm.predict(curr_num)[1]
            result = int(result[0, 0])

            if result <= 9: 
                # Nếu là số, đưa vào chuỗi kết quả luôn
                result = str(result)
            else: 
                # Nếu là chữ, chuyển đổi sang số bằng mã ASCII
                # Sau đó mới đưa vào chuỗi kết quả
                result = chr(result)

            # Gán chuỗi tạm vào chuỗi sau cùng
            plate_info +=result

plt.imshow(roi)

# %% [markdown]
# #### 2.7. Hiển thị

# %%
    # Ghi thông tin biển số lên trên ảnh
    cv2.putText(Ivehicle,fine_tune(plate_info),(50, 50), cv2.FONT_HERSHEY_PLAIN, 3.0, (0, 0, 255), lineType=cv2.LINE_AA)

    # Hiện thị kết quả cuối cùng
    print("Bien so =", plate_info)
    plt.imshow(Ivehicle)

# %% [markdown]
# ### **3. Hiện thực toàn bộ**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/ttvhh/CS114.K21

# %%
# !unrar x "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data.rar" "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/"
#!unzip "/content/drive/My Drive/desktop1.zip" -d "/content/drive/My Drive/"

# %%
# !pip install -r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from -r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 1)) (4.1.2.30)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from -r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (2.3.1)
# Collecting tensorflow==1.15.0
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 36kB/s
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/1d/d8/521db389ff0aae32035bfda6ed39cb2c2e28521c47015f6431f07460c50a/pytesseract-0.3.4.tar.gz
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 1)) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 2)) (1.0.8)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 37.6MB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (1.30.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (3.3.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (3.12.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (0.9.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 32.7MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (0.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 4)) (7.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (49.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->-r /content/CS114.K21/Automatic_License_Plate_Detection_SVM/setup.txt (line 3)) (3.1.0)
# Building wheels for collected packages: pytesseract, gast
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.4-py2.py3-none-any.whl size=13431 sha256=f2f6105c559918a2c3de8427658d09455f6ccb9e2aaf270c7d1e128b901c73db
#   Stored in directory: /root/.cache/pip/wheels/63/2a/a0/7596d2e0a73cf0aeffd6f6170862c4e73f3763b7827e48691a
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=18de0f471e2b71aea1775d0194341ffa7ec86cd297ec5b880324030a9d252fa2
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built pytesseract gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, gast, tensorboard, tensorflow, pytesseract
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# Successfully installed gast-0.2.2 pytesseract-0.3.4 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %% [markdown]
# #### 3.1. Train model SVM

# %%
import cv2
import os
import numpy as np
import glob

digit_w = 30
digit_h = 60

write_path="/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data"

def get_digit_data(path):#:, digit_list, label_list):

    digit_list = []
    label_list = []

    for number in range(10):
        i=0
        for img_org_path in glob.iglob(path + str(number) + '/*.jpg'):
            print(img_org_path)
            img = cv2.imread(img_org_path, 0)
            img = np.array(img)
            img = img.reshape(-1, digit_h * digit_w)

            print(img.shape)

            digit_list.append(img)
            label_list.append([int(number)])

    for number in range(65, 91):
        #number = chr(number)
        print(number)
        i=0
        for img_org_path in glob.iglob(path + str(number) + '/*.jpg'):
            print(img_org_path)
            img = cv2.imread(img_org_path, 0)
            img = np.array(img)
            img = img.reshape(-1, digit_h * digit_w)

            print(img.shape)

            digit_list.append(img)
            label_list.append([int(number)])

    return  digit_list, label_list

# Lấy dữ liệu từ đường dẫn github
digit_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/"
digit_list, label_list = get_digit_data(digit_path)

digit_list = np.array(digit_list, dtype=np.float32)
digit_list = digit_list.reshape(-1, digit_h * digit_w)

label_list = np.array(label_list)
label_list = label_list.reshape(-1, 1)

# Tạo model rỗng
svm_model = cv2.ml.SVM_create()

# Cấu hình công thức liên quan
svm_model.setType(cv2.ml.SVM_C_SVC)

# Khởi tạo với 1 trong nhiều kernels đã được địng nghĩa từ trước
# Ở đây chọn kernel INTER - Histogram Intersection Kernel
svm_model.setKernel(cv2.ml.SVM_INTER)

svm_model.setTermCriteria((cv2.TERM_CRITERIA_MAX_ITER, 100, 1e-6))

# Train model 
svm_model.train(digit_list, cv2.ml.ROW_SAMPLE, label_list)

# Lưu dữ liệu phục vụ cho các công đoạn sau
svm_model.save("svm.xml")
# Out:
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46513_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/9221.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46631_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46610_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47015_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46304_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46937_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46378_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46848_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46574_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46314_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46817_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46697_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46454_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46946_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46587_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/2575.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46549_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46888_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46813_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46905_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46373_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46906_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46410_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/1163.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46514_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46355_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46369_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46468_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46512_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46565_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46762_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46513_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46713_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46697_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46594_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46883_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46926_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47003_9.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46581_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46918_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46538_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46368_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46326_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46367_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46921_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46685_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46681_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46608_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47008_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46553_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46410_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46817_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46822_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/7075.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46793_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46505_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/47004_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46551_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46527_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46325_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46914_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/0/46639_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46396_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46331_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46702_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46519_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46514_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46457_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46685_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46513_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46567_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46540_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46464_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46321_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46410_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46468_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46556_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44680_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46507_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46514_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46329_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46392_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46651_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46567_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46425_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46707_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46368_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46518_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44688_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46512_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46392_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46436_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46524_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46376_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/6498.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46454_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46713_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46457_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/1817.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46707_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46378_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46601_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46321_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46548_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46540_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/44688_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/6490.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46584_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46524_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46651_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46713_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46434_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46608_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/46502_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/1/759.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46839_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46513_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46518_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/27.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/51797_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46639_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46588_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48404_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48500_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46563_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46505_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46550_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47292_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46423_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46514_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46311_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46548_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46359_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1995_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1881_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46878_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46403_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46440_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1995_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48936_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/194918_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49249_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46310_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46373_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/44682_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46538_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46359_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/51396_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2018.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46434_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49146_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47047_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/192901_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46608_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47954_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48166_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46440_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49191_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/49001_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48454_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46570_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46464_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46567_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46328_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46310_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46607_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46691_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48803_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46542_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46397_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48446_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46527_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/48337_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2045_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46710_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/2052_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/46311_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/2/47060_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/50798_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/1371.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47959_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/191694_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47959_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/21041.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47703_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46388_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46524_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/3778.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/46811_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48179_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48019_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/1463.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/47082_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/50221_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/9223.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/3/48822_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46367_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46356_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46310_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46305_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46311_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/46325_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/4/44688_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46310_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46359_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3925_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46570_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3987_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48959_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46354_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46538_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46423_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3925_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48239_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46572_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46310_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46374_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46628_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46368_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/48959_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46431_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46531_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46588_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/195079_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/7518.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/47174_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46587_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46305_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46366_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46551_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46397_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/6753.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46519_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46348_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46325_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46378_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46392_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46542_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46392_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46628_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/47549_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46457_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46329_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/3962_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46425_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46588_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46367_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46403_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46587_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46304_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46434_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46311_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46519_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/53510_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46320_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/49041_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46359_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46505_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46373_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46329_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46328_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/8697.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46527_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46530_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46610_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/46572_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/5/1672.0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46392_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2558.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46314_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46396_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46563_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46348_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44680_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46591_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46464_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44680_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46427_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46321_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46518_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46314_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46304_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46507_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46326_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46325_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46359_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46463_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46584_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46505_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46553_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46651_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46601_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46328_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46685_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46331_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/6783.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46427_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46354_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46366_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46355_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46514_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46376_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46542_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46366_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/4640.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46463_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46621_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46527_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46705_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46608_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/9404.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44682_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46464_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46457_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/44688_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/46702_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/6/2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/49172_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/49099_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48118_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48304_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48140_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48996_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46531_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46463_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46304_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46549_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46513_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46549_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48905_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48118_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48341_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46545_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/48910_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/3603.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46304_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46427_8.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/7/46530_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47015_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46443_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/8593.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47043_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/7869.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46697_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/44680_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46702_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47015_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46553_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47108_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47187_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47067_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47082_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46685_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47038_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46308_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46524_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47038_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47122_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46437_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47045_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46321_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/2647.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46847_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46567_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47205_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47022_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46308_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46629_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47061_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47262_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46781_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46882_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46464_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46519_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46930_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/47042_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/8/46601_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52221_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52227_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/194961_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52189_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52531_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52530_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52635_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52278_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46584_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/2318.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52201_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/48341_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52272_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52504_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52500_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52100_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/9.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52515_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52496_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52157_7.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52167_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/2858.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52089_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/48341_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52185_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52091_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52278_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46709_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52297_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46964_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52264_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52566_4.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52636_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52530_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/46843_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52139_5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52239_6.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/9/52562_5.jpg
# (1, 1800)
# 65
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/1800.5.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46527_0 copy.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/50400_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/53776_1 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0 copy 2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/46423_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/65/52003_0.jpg
# (1, 1800)
# 66
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46880_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/44682_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46685_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47338_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48203_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48340_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46507_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48183_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46553_3.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48434_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46930_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47443_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48476_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47694_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47263_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48146_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47165_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47880_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47657_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47781_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47611_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48361_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47595_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46898_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48381_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46948_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47536_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46457_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46356_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46712_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47631_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47556_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46551_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47819_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46359_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47526_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47519_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47820_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46376_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46348_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46321_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47365_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48316_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46567_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46942_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47267_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47262_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46329_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48004_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47132_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/46331_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47047_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/48412_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/66/47764_1.jpg
# (1, 1800)
# 67
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46514_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46607_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46815_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46601_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48069_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46710_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48111_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47292_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46818_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46693_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46665_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48046_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47012_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46328_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47006_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46540_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46513_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46714_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47053_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47947_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47203_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47023_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/44688_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47074_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/44680_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46621_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47015_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47555_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47341_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46807_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/46707_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/48192_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47416_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47390_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/67/47060_1.jpg
# (1, 1800)
# 68
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/47311_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/48068_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/68/51841_7.jpg
# (1, 1800)
# ...
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52259_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52594_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/51370_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/49162_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/51826_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/50178_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/48015_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/48990_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/192933_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/47389_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/46610_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/194745_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/52198_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/49091_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/80/53098_1.jpg
# (1, 1800)
# 81
# 82
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/53768_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52760_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50335_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51906_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/49493_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48138_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/53478_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/192936_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48121_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/47818_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52636_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48729_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50081_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/193028_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51741_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51487_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/49483_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48888_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/46681_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50221_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51600_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50105_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51212_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/52569_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/194511_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/51549_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/50344_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/48097_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/82/47251_2.jpg
# (1, 1800)
# 83
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/47768_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/47591_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/192770_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/53581_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/52151_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/49638_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48591_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/193213_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/194945_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/52406_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/194582_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48187_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/48537_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/83/192320_1.jpg
# (1, 1800)
# 84
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46320_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46631_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46556_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/48463_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/84/46373_1.jpg
# (1, 1800)
# 85
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/52750_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194986_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/48613_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193917_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/53472_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47905_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193216_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46922_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/192265_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46937_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/48449_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/50957_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194198_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193651_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193208_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46935_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/52226_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/49563_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/195194_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/49572_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47004_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51098_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/191922_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46397_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/192944_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51870_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51996_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/193119_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194219_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/53277_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/47642_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/194001_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/46403_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/85/51932_1.jpg
# (1, 1800)
# 86
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46305_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/192252_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46355_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191610_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/46964_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/47413_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/47018_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/193231_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191582_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191929_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/86/191745_1.jpg
# (1, 1800)
# 87
# 88
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47170_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47588_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192238_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46375_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191899_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/48853_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46955_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191793_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46888_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191819_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46954_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191854_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47188_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191784_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46367_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192361_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47117_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191600_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46691_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192383_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191567_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191759_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47370_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46311_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47891_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192195_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47206_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/47596_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/192052_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/191751_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46907_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/88/46779_1.jpg
# (1, 1800)
# 89
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193054_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193504_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/47471_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/194806_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/49308_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/52500_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/194966_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/53642_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/46959_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/49253_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193050_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/46841_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/193572_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/50271_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/50930_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/192102_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/48548_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/89/51807_0.jpg
# (1, 1800)
# 90
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3558_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47560_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/193092_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46822_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46550_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3758_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/52374_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48063_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47220_0.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47866_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3762_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/192204_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/50728_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48336_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/51946_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46454_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46705_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/49113_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46903_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/3469_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/49559_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/48165_1.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/47949_2.jpg
# (1, 1800)
# /content/CS114.K21/Automatic_License_Plate_Detection_SVM/data/90/46463_3.jpg
# (1, 1800)

# %% [markdown]
# #### 3.2. Pre-trained License Plate Detection Model (WPOD-net)

# %%
# pylint: disable=invalid-name, redefined-outer-name, missing-docstring, non-parent-init-called, trailing-whitespace, line-too-long
from os.path import splitext
import cv2
import numpy as np
from keras.models import model_from_json


class Label:
    def __init__(self, cl=-1, tl=np.array([0., 0.]), br=np.array([0., 0.]), prob=None):
        self.__tl = tl
        self.__br = br
        self.__cl = cl
        self.__prob = prob

    def __str__(self):
        return 'Class: %d, top left(x: %f, y: %f), bottom right(x: %f, y: %f)' % (
        self.__cl, self.__tl[0], self.__tl[1], self.__br[0], self.__br[1])

    def copy(self):
        return Label(self.__cl, self.__tl, self.__br)

    def wh(self): return self.__br - self.__tl

    def cc(self): return self.__tl + self.wh() / 2

    def tl(self): return self.__tl

    def br(self): return self.__br

    def tr(self): return np.array([self.__br[0], self.__tl[1]])

    def bl(self): return np.array([self.__tl[0], self.__br[1]])

    def cl(self): return self.__cl

    def area(self): return np.prod(self.wh())

    def prob(self): return self.__prob

    def set_class(self, cl):
        self.__cl = cl

    def set_tl(self, tl):
        self.__tl = tl

    def set_br(self, br):
        self.__br = br

    def set_wh(self, wh):
        cc = self.cc()
        self.__tl = cc - .5 * wh
        self.__br = cc + .5 * wh

    def set_prob(self, prob):
        self.__prob = prob

class DLabel(Label):
    def __init__(self, cl, pts, prob):
        self.pts = pts
        tl = np.amin(pts, axis=1)
        br = np.amax(pts, axis=1)
        Label.__init__(self, cl, tl, br, prob)

# Hàm normalize ảnh
def im2single(Image):
    return Image.astype('float32') / 255

def getWH(shape):
    return np.array(shape[1::-1]).astype(float)

def IOU(tl1, br1, tl2, br2):
    wh1, wh2 = br1-tl1, br2-tl2
    assert((wh1 >= 0).all() and (wh2 >= 0).all())
    
    intersection_wh = np.maximum(np.minimum(br1, br2) - np.maximum(tl1, tl2), 0)
    intersection_area = np.prod(intersection_wh)
    area1, area2 = (np.prod(wh1), np.prod(wh2))
    union_area = area1 + area2 - intersection_area
    return intersection_area/union_area

def IOU_labels(l1, l2):
    return IOU(l1.tl(), l1.br(), l2.tl(), l2.br())

def nms(Labels, iou_threshold=0.5):
    SelectedLabels = []
    Labels.sort(key=lambda l: l.prob(), reverse=True)
    
    for label in Labels:
        non_overlap = True
        for sel_label in SelectedLabels:
            if IOU_labels(label, sel_label) > iou_threshold:
                non_overlap = False
                break

        if non_overlap:
            SelectedLabels.append(label)
    return SelectedLabels

def load_model(path):
    try:
        path = splitext(path)[0]
        with open('%s.json' % path, 'r') as json_file:
            model_json = json_file.read()
        model = model_from_json(model_json, custom_objects={})
        model.load_weights('%s.h5' % path)
        print("Loading model successfully...")
        return model
    except Exception as e:
        print(e)

def find_T_matrix(pts, t_pts):
    A = np.zeros((8, 9))
    for i in range(0, 4):
        xi = pts[:, i]
        xil = t_pts[:, i]
        xi = xi.T
        
        A[i*2, 3:6] = -xil[2]*xi
        A[i*2, 6:] = xil[1]*xi
        A[i*2+1, :3] = xil[2]*xi
        A[i*2+1, 6:] = -xil[0]*xi

    [U, S, V] = np.linalg.svd(A)
    H = V[-1, :].reshape((3, 3))
    return H

def getRectPts(tlx, tly, brx, bry):
    return np.matrix([[tlx, brx, brx, tlx], [tly, tly, bry, bry], [1, 1, 1, 1]], dtype=float)

def normal(pts, side, mn, MN):
    pts_MN_center_mn = pts * side
    pts_MN = pts_MN_center_mn + mn.reshape((2, 1))
    pts_prop = pts_MN / MN.reshape((2, 1))
    return pts_prop

# Hàm tái tạo từ predict value thành biến số, cắt từ ảnh chính ra biển số,  nhãn...
def reconstruct(I, Iresized, Yr, lp_threshold):
    # 4 max-pooling layers, stride = 2
    net_stride = 2**4
    side = ((208 + 40)/2)/net_stride

    # Kích thước biển số
    # Biển ngang (1 dòng)
    one_line = (470, 110)

    # Biển vuông (2 dòng)
    two_lines = (280, 200)

    Probs = Yr[..., 0]
    Affines = Yr[..., 2:]

    xx, yy = np.where(Probs > lp_threshold)
  
    WH = getWH(Iresized.shape)
    MN = WH/net_stride

    # alpha
    vxx = vyy = 0.5 
    base = lambda vx, vy: np.matrix([[-vx, -vy, 1], [vx, -vy, 1], [vx, vy, 1], [-vx, vy, 1]]).T
    labels = []
    labels_frontal = []

    for i in range(len(xx)):
        x, y = xx[i], yy[i]
        affine = Affines[x, y]
        prob = Probs[x, y]

        mn = np.array([float(y) + 0.5, float(x) + 0.5])

        # affine transformation matrix
        A = np.reshape(affine, (2, 3))
        A[0, 0] = max(A[0, 0], 0)
        A[1, 1] = max(A[1, 1], 0)
        # identity transformation
        B = np.zeros((2, 3))
        B[0, 0] = max(A[0, 0], 0)
        B[1, 1] = max(A[1, 1], 0)

        pts = np.array(A*base(vxx, vyy))
        pts_frontal = np.array(B*base(vxx, vyy))

        pts_prop = normal(pts, side, mn, MN)
        frontal = normal(pts_frontal, side, mn, MN)

        labels.append(DLabel(0, pts_prop, prob))
        labels_frontal.append(DLabel(0, frontal, prob))

    final_labels = nms(labels, 0.1)
    final_labels_frontal = nms(labels_frontal, 0.1)

    print(final_labels_frontal)


    # LP size and type
    out_size, lp_type = (two_lines, 2) if ((final_labels_frontal[0].wh()[0] / final_labels_frontal[0].wh()[1]) < 1.7) else (one_line, 1)

    TLp = []
    if len(final_labels):
        final_labels.sort(key=lambda x: x.prob(), reverse=True)
        for _, label in enumerate(final_labels):
            t_ptsh = getRectPts(0, 0, out_size[0], out_size[1])
            ptsh = np.concatenate((label.pts * getWH(I.shape).reshape((2, 1)), np.ones((1, 4))))
            H = find_T_matrix(ptsh, t_ptsh)

            Ilp = cv2.warpPerspective(I, H, out_size, borderValue=0)
            TLp.append(Ilp)
    print(final_labels)
    return final_labels, TLp, lp_type

def detect_lp(model, I, max_dim, lp_threshold):

    # Tính factor resize ảnh
    min_dim_img = min(I.shape[:2])
    factor = float(max_dim) / min_dim_img

    # Tính W và H mới sau khi resize
    w, h = (np.array(I.shape[1::-1], dtype=float) * factor).astype(int).tolist()

    # Tiến hành resize ảnh
    Iresized = cv2.resize(I, (w, h))

    T = Iresized.copy()

    # Chuyển thành Tensor
    T = T.reshape((1, T.shape[0], T.shape[1], T.shape[2]))

    # Tiến hành detect biển số bằng pre-trained WPOD-net
    Yr = model.predict(T)

    # Remove các chiều = 1 của Yr
    Yr = np.squeeze(Yr)

    print(Yr.shape)

    # Tái tạo và trả về các biến gồm: 
    # - Nhãn 
    # - Ảnh biến số
    # - Loại biển số 
    #   + 1: dài
    #   + 2: vuông
    L, TLp, lp_type = reconstruct(I, Iresized, Yr, lp_threshold)

    return L, TLp, lp_type
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 3.3. Detect và hiển thị các chữ số

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
#from lib_detection import load_model, detect_lp, im2single

# Định nghĩa các ký tự có mặt trên biển số
char_list =  '0123456789ABCDEFGHKLMNPRSTUVXYZ'

# Hàm fine_tune dùng để loại bỏ các ký tự không liên quan
def fine_tune(lp):
    newString = ""
    for i in range(len(lp)):
        if lp[i] in char_list:
            newString += lp[i]
    return newString

# Hàm sắp xếp các contour từ trái sang phải theo đúng trật tự
def sort_contours(cnts):

    reverse = False
    i = 0
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes), key=lambda b: b[1][i], reverse=reverse))
    return cnts

def show_images(images, cols = 1, titles = None):
    
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# Đường dẫn ảnh
img_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/test/test12.jpg"

# Load pre-trained license plate detecting model (WPOD-net)
wpod_net_path = "/content/CS114.K21/Automatic_License_Plate_Detection_SVM/wpod-net_update1.json"
wpod_net = load_model(wpod_net_path)

# Đọc file ảnh đầu vào
Ivehicle = cv2.imread(img_path)

# Khởi tạo kích thước lớn nhất và nhỏ nhất của 1 chiều ảnh
Dmax = 608
Dmin = 288

# Lấy tỷ lệ giữa W và H của ảnh và tìm ra chiều nhỏ nhất
ratio = float(max(Ivehicle.shape[:2])) / min(Ivehicle.shape[:2])
side = int(ratio * Dmin)
bound_dim = min(side, Dmax)

_ , LpImg, lp_type = detect_lp(wpod_net, im2single(Ivehicle), bound_dim, lp_threshold=0.5)

# Cấu hình tham số cho OCR model (SVM)
# Kích thước kí tự
digit_w = 30 # Width
digit_h = 60 # Height

# Load model
model_svm = cv2.ml.SVM_load('/content/CS114.K21/Automatic_License_Plate_Detection_SVM/svm.xml')

if (len(LpImg)):

    # Chuyển đổi ảnh biển số
    # Scale, tính toán các giá trị tuyệt đối và sau đó chuyển đổi kết quả sang dạng 8-bit
    LpImg[0] = cv2.convertScaleAbs(LpImg[0], alpha=(255.0))
    roi = LpImg[0]

    # Áp dụng kỹ thuật Grayscale Conversion để chuyển đổi ảnh biển số về ảnh xám
    gray = cv2.cvtColor( LpImg[0], cv2.COLOR_BGR2GRAY)
    

    # Áp dụng Threshold Binary, Inverted để phân tách số và nền
    binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)[1]

    # Segment kí tự
    kernel3 = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    thre_mor = cv2.morphologyEx(binary, cv2.MORPH_DILATE, kernel3)
    cont, _  = cv2.findContours(thre_mor, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

    # Khởi tạo chuỗi rỗng để lưu trữ thông tin biển số
    plate_info = ""

    for c in sort_contours(cont):
        (x, y, w, h) = cv2.boundingRect(c)

        # Tỉ lệ h/w dùng để lọc những ký tự không liên quan
        ratio = h/w

        # Chọn các contour thỏa mãn yêu cầu tỉ lệ h/w phải nằm trong 
        # khoảng từ 1.5 đến 3.5
        if 1.5 <= ratio <= 3.5: 

            # Áp dụng kết quả sau khi áp dụng kĩ thuật ROI 
            # để chọn các contour có chiều cao từ 60% chiều cao biển số
            if h/roi.shape[0]>=0.6:

                # Vẽ khung chữ nhật quanh chữ số
                cv2.rectangle(roi, (x, y), (x + w, y + h), (0, 255, 0), 2)

                # Tách số và resize
                curr_num = thre_mor[y:y+h,x:x+w]
                curr_num = cv2.resize(curr_num, dsize=(digit_w, digit_h))
                
                # Áp dụng ROI - Region of Interest
                _, curr_num = cv2.threshold(curr_num, 30, 255, cv2.THRESH_BINARY)
                curr_num = np.array(curr_num,dtype=np.float32)
                curr_num = curr_num.reshape(-1, digit_w * digit_h)

                # Load vào model SVM
                result = model_svm.predict(curr_num)[1]
                result = int(result[0, 0])

                if result <= 9: 
                    # Nếu là số, đưa vào chuỗi kết quả luôn
                    result = str(result)
                else: 
                    # Nếu là chữ, chuyển đổi sang số bằng mã ASCII
                    # Sau đó mới đưa vào chuỗi kết quả
                    result = chr(result)

                # Gán chuỗi tạm vào chuỗi sau cùng
                plate_info +=result

    #cv2.imshow("Cac contour tim duoc", roi)
    
    # Ghi thông tin biển số lên trên ảnh
    cv2.putText(Ivehicle,fine_tune(plate_info),(50, 50), cv2.FONT_HERSHEY_PLAIN, 3.0, (0, 0, 255), lineType=cv2.LINE_AA)

    # Hiện thị kết quả cuối cùng
    print("Bien so =", plate_info)
    figs = np.array([gray, binary, roi, Ivehicle])
    show_images(figs, 4, ["Grayscale", "Threshold Binary, Inverted", "ROI", "Result"])
    #plt.imshow(gray)
    #plt.imshow(binary)
    #plt.imshow(roi)
    #plt.imshow(Ivehicle)
    #cv2.imshow("Hinh anh output",Ivehicle)
# Out:
# Loading model successfully...
# (24, 32, 8)
# [<__main__.DLabel object at 0x7f1689ce5048>]
# [<__main__.DLabel object at 0x7f1689ce50b8>]
# Bien so = 60A99999
